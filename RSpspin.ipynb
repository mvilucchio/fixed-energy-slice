# %%
import matplotlib.pyplot as plt
import scipy
from tqdm.notebook import tqdm
from scipy.optimize import fmin, minimize, root_scalar

# %load_ext autoreload
# %autoreload 2

# %%
from integrals import *

# %% [markdown]
# ## RS computation

# %%
p = 5
n_points_m = 1_000
n_points_T = 10

T_kauz, T_dyn = 0.60695, 0.7001

# %%
Teqs = np.hstack((np.linspace(T_kauz, T_dyn, n_points_T - 1), np.array([(n_points_T * T_dyn -T_kauz) / (n_points_T - 1),])))

es = -1 / (2 * Teqs)

# %%
ms = np.linspace(0.0, 0.99, n_points_m)

data = observables((len(Teqs), n_points_m))

for jdx, e in enumerate(tqdm(es)):
    for idx, m in enumerate(ms):
        h, q = fixed_points_h_q(m, e, p)

        data['q'][jdx, idx] = q
        data['h'][jdx, idx] = h
        data['T'][jdx, idx] = 1 / beta_q_e(q, m, e, p)
        data['delta_f'][jdx, idx] = deltaf_FP(m, q, h, p, e)
        data['s'][jdx, idx] = s_FP(m, q, h, p, e)
        data['dAT'][jdx, idx] = dAT_condition(
            q, m, h, beta_q_e(q, m, e, p), beta_q_e(q, m, e, p) / 2, p
        )
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
Teqs_list = [str(x) for x in Teqs.tolist()]

fig, axs = plt.subplots(2, 3, figsize=(12, 8))
fig.suptitle(f'p={p}')

for jdx, e in enumerate(es):
    legend_name = f'e={e:.3f}'
    if jdx == 0:
        legend_name = r'$- 1/2T_k$'
    if jdx == len(es) - 2:
        legend_name = r'$ - 1/2T_d$'

    for idx, (key, item) in enumerate(data.items()):
        axs[idx // 3 , idx % 3].plot(ms, item[jdx,:], '-', label=legend_name)
        axs[idx // 3 , idx % 3].set_ylabel(key)
        axs[idx // 3 , idx % 3].set_xlabel('m')
        axs[idx // 3 , idx % 3].grid(True)

position_T = list(data.keys()).index('T')
axs[position_T // 3 , position_T % 3].axhline(y=T_kauz, color='r', linestyle='--', label=r'$T_k$')
axs[position_T // 3 , position_T % 3].axhline(y=T_dyn, color='g', linestyle='--', label=r'$T_d$')

position_dAT = list(data.keys()).index('dAT')
axs[position_dAT // 3 , position_dAT % 3].axhline(y=0, color='k', linestyle=':', label=r'$\Delta A = 0$')

handles, labels = [], []
# for ax in axs.flat:
ax = axs[0,1]
for handle, label in zip(*ax.get_legend_handles_labels()):
    if (handle, label) not in zip(handles, labels):
        handles.append(handle)
        labels.append(label)

fig.legend(handles, labels, loc='center left', bbox_to_anchor=(-0.1, 0.5))

plt.tight_layout(rect=[0.1, 0, 1, 1]) 

plt.tight_layout()
fig.savefig(f'FPpspin_p{p}.png')

# %% [markdown]
# ### dashed non-dashed

# %%
fig, axs = plt.subplots(1, 1, figsize=(8, 6))
fig.suptitle(f"p={p}")
e_string = ["1/2(" + str(x) + ")" for x in Teqs.tolist()]
e_string[1] = r"$1/2T_k$"
e_string[-2] = r"$1/2T_d$"

for jdx, e in enumerate(es):
    color = axs._get_lines.get_next_color()
    stable_idxs = dAT_cond[jdx, :] > 0

    if np.all(stable_idxs):
        axs.plot(ms, entropys[jdx, :], "-", label=f"e={e_string[jdx]}", color=color)
    else:
        i_start, i_end = np.where(np.diff(np.r_[True, stable_idxs, True]) == True)[0]

        axs.plot(ms[:i_start], entropys[jdx, :i_start], "-", label=f"e={e_string[jdx]}", color=color)
        axs.plot(ms[i_end:], entropys[jdx, i_end:], "-", color=color)

        axs.plot(ms[~stable_idxs], entropys[jdx, ~stable_idxs], "--", color=color, alpha=0.5)

axs.set_ylabel("s(m)")
axs.set_xlabel("m")

handles, labels = [], []
for handle, label in zip(*axs.get_legend_handles_labels()):
    if (handle, label) not in zip(handles, labels):
        handles.append(handle)
        labels.append(label)

fig.legend(handles, labels, loc="center right", bbox_to_anchor=(1.2, 0.5))

plt.tight_layout(rect=[0.1, 0, 1, 1])

axs.grid()
plt.tight_layout()
fig.savefig(f'entropy_dashed_p{p}.png')

# %% [markdown]
# ## 2d plot

# %%
p = 5
blend = 0.85
ms = np.linspace(0.0, 0.99, 1_000)
Teqs = np.linspace(0.60695, 0.72, 100)

es = -1 / (2 * Teqs)

Temps = np.empty((len(es), len(ms)))
qs = np.empty((len(Temps), len(ms)))
hs = np.empty((len(Temps), len(ms)))
fs = np.empty((len(Temps), len(ms)))
deltafs = np.empty((len(Temps), len(ms)))
entropys = np.empty((len(Temps), len(ms)))
dAT_cond = np.empty((len(Temps), len(ms)))

for jdx, e in enumerate(tqdm(es)):
    for idx, m in enumerate(ms):
        err = 1
        q = m
        h = 0.1

        while err > 1e-9:
            h_new = root_scalar(
                lambda h: compute_m_FP(m, q, h, p, e) - m, bracket=[-20, 20], xtol=1e-12
            ).root
            q_new = compute_q_FP(m, q, h_new, p, e)

            err = max(abs(h_new - h), abs(q_new - q))
            h = blend * h + (1 - blend) * h_new
            q = blend * q + (1 - blend) * q_new

        qs[jdx, idx] = q
        hs[jdx, idx] = h
        Temps[jdx, idx] = 1 / beta_q_e(q, m, e)
        fs[jdx, idx] = f_FP(m, q, h, p, e)
        deltafs[jdx, idx] = deltaf_FP(m, q, h, p, e)
        entropys[jdx, idx] = s_FP(m, q, h, p, e)
        dAT_cond[jdx, idx] = dAT_condition(
            q, m, h, beta_q_e(q, m, e), beta_q_e(q, m, e) / 2, p
        )
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")

ax.view_init(30, -70)

m_mesh, es_mesh = np.meshgrid(ms, es)
# z = np.zeros_like(m_mesh)

positive_idx = entropys > 0
print(entropys[positive_idx].shape)
print(np.where(positive_idx, entropys, np.nan).shape)

surf = ax.plot_surface(np.where(positive_idx, m_mesh, np.nan), np.where(positive_idx, es_mesh, np.nan), np.where(positive_idx, entropys, np.nan), cmap="viridis", edgecolor="none")
# ax.plot_surface(m_mesh, es_mesh, z, color="black", alpha=0.5, edgecolor="none")

ax.grid(False)
ax.xaxis.pane.fill = False
ax.yaxis.pane.fill = False
ax.zaxis.pane.fill = False
fig.colorbar(surf, shrink=0.5, aspect=5, pad=0.1)

ax.set_xlabel("m")
ax.set_ylabel("e")
ax.set_zlabel("s(m,e)")
ax.set_title(f"p = {p:d}")
# Out:
# (93380,)
# (100, 1000)
# Text(0.5, 0.92, 'p = 5')

# %%
num_levels = 15

plt.figure(figsize=(8, 6))

# Create a filled contour plot
c1 = plt.contourf(m_mesh, es_mesh, entropys, cmap="viridis", levels=num_levels)
cbar = plt.colorbar(c1)  # Optional: Add a colorbar

# Overlay a contour plot with black lines
plt.contour(m_mesh, es_mesh, entropys, colors="black", levels=num_levels, alpha=0.5)

plt.contour(m_mesh, es_mesh, entropys, levels=[0], colors='red')

zmin, zmax = entropys.min(), entropys.max()
position = (0 - zmin) / (zmax - zmin)

# Draw the line
cbar.ax.axhline(position, color='red')

# Add titles and labels
plt.title("s(m,e)")
plt.xlabel("m")
plt.ylabel("e")
# Out:
# Text(0, 0.5, 'e')

# %% [markdown]
# ### Find $T_{sh}$

# %%
# Plot s(m) as the plot above

fig, ax = plt.subplots(1, 1, figsize=(9, 5))
fig.suptitle(f'p={p}')  
for jdx, e in enumerate(es):
    ax.plot(ms, entropys[jdx,:], '-', label=f'e={e_string[jdx]}')
ax.set_ylabel('s(m)')
ax.set_xlabel('m')
ax.legend()
ax.grid()

ax.set_xlim(0.6, 0.8)
ax.set_ylim(-0.02, 0.02)
# Out:
# (-0.02, 0.02)

# %%
fig, ax = plt.subplots(1, 1, figsize=(9, 6))
fig.suptitle(f'Entropy, p={p}')
for jdx, T in enumerate(Temps):
    ax.plot(ms, entropys[jdx,:], '-', label=f'T={T}')
ax.set_xlabel('m')
ax.set_ylabel('s(m)')
ax.axhline(0, color='black', lw=1)
ax.legend()
ax.grid()

# %% [markdown]
# ### Definition of the functions

# %% [markdown]
# Gradient of the function

# %%
@njit()
def smooth_function(x, e1, e2):
    if x < 1:
        return x ** e1
    else:
        return x ** e2

def fun_to_min_scipy(x, m, e, exp1, exp2):
    J0 = x[0]
    q = x[1]
    if q > 1 or q < 0:
        return 1e15
    return (
        smooth_function(abs(m - compute_m(m, J0, q, e)), exp1, exp2)
        + smooth_function(abs(q - compute_q(m, J0, q, e)), exp1, exp2)
    )

# %%
x_init = np.array([8.85, 0.009])
x_init = np.array([10, 0.14])
m = 0.5
e = -0.2

res = fmin(
    fun_to_min_scipy, x0=x_init, args=(m, e, 0.5, 2), xtol=1e-10, full_output=True
)

print(res)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.000005
#          Iterations: 103
#          Function evaluations: 193
# (array([1.82614507, 0.2592403 ]), 4.65840797082507e-06, 103, 193, 0)

# %% [markdown]
# Fixed E sweep in m

# %%
e = -0.8
ms = np.linspace(0.01, 1.0, 10_000)
x_init = np.array([25, 0.0001])

m_valid = []
s_tab = []
beta_tab = []

for idx, m in enumerate(tqdm(ms)):
    res = fmin(
        fun_to_min_scipy,
        x0=x_init,
        args=(m, e, 0.7, 2),
        xtol=1e-13,
        disp=False,
        full_output=True,
    )
    x_init = res[0]
    J0 = x_init[0]
    q = x_init[1]

    try:
        beta = beta_q_e(q, e)
    except:
        print("beta problem")
        break

    if res[1] > 1e-7:
        print("m = ", m, " did not converge, error = ", res[1])
        print("J0 = ", J0, " q = ", q, " beta = ", beta)
        break

    s = compute_s(m, J0, q, e)

    m_valid.append(m)
    s_tab.append(s)
    beta_tab.append(beta)
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# m =  0.5708910891089108  did not converge, error =  5.197178986688962e-06
# J0 =  0.7901727953720576  q =  0.9998483465151049  beta =  3517.3225576637396

# %%
plt.clf()
plt.figure(figsize=(8, 6))

plt.plot(m_valid, s_tab)

plt.axhline(0, color='black', lw=0.5)
plt.xlabel("m")
plt.ylabel("s")
plt.grid()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
print(m_valid[-5:])
print(s_tab[-5:])
# Out:
# [0.5703960396039603, 0.5704950495049504, 0.5705940594059405, 0.5706930693069306, 0.5707920792079207]
# [inf, inf, inf, inf, inf]

# %% [markdown]
# ### Sweep of $q$ solution as function of $J0$

# %%
e = -0.3
m = 0.9

# %%
blend = 0.4
J0s = np.linspace(0.0, 0.8, 20_000)

J0s_valid = []
q_valid = []

q_init_0 = 0.994

dif_es = np.linspace(-0.3, -0.8, 20)

for e in tqdm(dif_es):
    J0_tmp = []
    q_tmp = []
    for idx, J0 in enumerate(J0s):
        err = 1
        q = q_init
        while err > 1e-15:
            q_new = compute_q(m, J0, q, e)

            q = blend * q_new + (1 - blend) * q
            err = abs(q - q_new)

        q_init = q

        J0_tmp.append(J0)
        q_tmp.append(q)

    J0s_valid.append(J0_tmp)
    q_valid.append(q_tmp)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]

# %%
plt.figure(figsize=(8, 6))

colors = plt.cm.viridis(np.linspace(0, 1, len(dif_es)))
for idx, (e, c) in enumerate(zip(dif_es, colors)):
    plt.plot(J0s_valid[idx], q_valid[idx], ".-", label=f"e = {e:.2f}", color=c)

plt.axhline(1, color='black', lw=0.5)

plt.xlabel("J0")
plt.ylabel("q")
plt.legend(loc='center left', bbox_to_anchor=(1.05, 0.5))
# plt.ylim(0.9,1)
# plt.xlim(0.3,0.8)
plt.grid()

plt.show()

# %% [markdown]
# ### Sweeps of $J0$ as a function of $q$

# %%
e = -0.3
m = 0.8

# %%
qs = np.linspace(0.1, 0.999, 1_000)
J0_init = 0.1

J0s_valid = []
q_valid = []

J0_init_0 = 0.1

dif_es = np.linspace(-0.3, -0.7, 15)


@njit()
def fun_to_min(x, m, q, e):
    J0 = x[0]
    added_term = 0.0
    if J0 < 0:
        added_term = 1e3
    return abs(q - compute_q(m, J0, q, e)) ** 1.5 + added_term


for e in tqdm(dif_es):
    J0s_tmp = []
    q_tmp = []

    for idx, q in enumerate(qs):
        res = minimize(
            fun_to_min,
            x0=J0_init,
            tol=1e-11,
            args=(m, q, e),
        )

        J0_init = res.x[0]

        if res.fun > 1e-10:
            print("q = ", q, " did not converge, error = ", res.fun)
            print("J0 = ", res.x[0])
            break

        J0s_tmp.append(res.x[0])
        q_tmp.append(q)

    J0s_valid.append(J0s_tmp)
    q_valid.append(q_tmp)

    q0s_second = np.array(q_valid)
    J0s_second = np.array(J0s_valid)
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]

# %%
colors = plt.cm.viridis(np.linspace(0, 1, len(dif_es)))
for idx, (e, c) in enumerate(zip(dif_es, colors)):
    plt.plot(q_valid[idx], J0s_valid[idx], ".-", label=f"e = {e:.2f}", color=c)

plt.title(f"m = {m:.3f}")
plt.xlabel("q")
plt.ylabel("J0")
plt.legend(loc='center left', bbox_to_anchor=(1.05, 0.5))
# plt.xlim(0.8,1)
# plt.ylim(0.27,0.35)
plt.grid()

plt.show()

# %% [markdown]
# ### Check which of the solutions is also solving first equation

# %%
value_first_residual = np.empty_like(q0s_second)

for idx, (q, J0) in enumerate(zip(q0s_second, J0s_second)):
    value_first_residual[idx] = abs(m - compute_m(m, J0, q, e))

# %%
plt.plot(q0s_second, value_first_residual)
plt.xlabel("q")
plt.ylabel("residual")
plt.yscale("log")
plt.grid()

plt.show()

# %% [markdown]
# ### Others

# %% [markdown]
# Functions for the iterations

# %%
def iterate_q(m, J0, q0, e, verbose=False):
    q_old = q0 + 1e-5
    q = q0
    while abs(q_old - q) > 1e-6:
        q_old = q
        q = compute_q(m, J0, q, e)
        if verbose:
            print(q)
    return q


def find_m(m, e, q0, J00, verbose=False):
    q = iterate_q(m, J00, q0, e, verbose=verbose)
    m = compute_m(m, J00, q, e)
    return m  # ,J00,q,e

# %% [markdown]
# ### Simulations

# %% [markdown]
# ##### Let's try the fixed point iterations

# %%
m = 0.9
J0 = 0.1
e = -0.7
q0 = 0.1

q = iterate_q(m, J0, q0, e, verbose=True)
# Out:
# 0.12492006440313871
# 0.13446955081873394
# 0.13861921230170082
# 0.1405032864415323
# 0.14137456405027193
# 0.14178079718654238
# 0.1419709172802272
# 0.14206005054113802
# 0.14210187268086313
# 0.1421215035195885
# 0.14213071966660418
# 0.14213504676237107
# 0.1421370784680261
# 0.142138032434545

# %% [markdown]
# #### 1) Bifurcation routine

# %% [markdown]
# ##### Let's try the iterations functions

# %%
m = 0.9
J0 = 0.1
e = -0.7
q0 = 0.5
find_m(m, e, q0, J0, verbose=False)
# Out:
# 0.31257509942014294

# %%
m = 0.8
e = -0.2
q0 = 0.5
J0star = scipy.optimize.root(lambda J0: find_m(m, e, q0, J0) - m, 1.0).x[0]
q = iterate_q(m, J0star, q0, e)
m = compute_m(m, J0star, q, e)
beta = beta_q_e(q, e)
s = compute_s(m, J0star, q, e)
print(m, J0star, q, e, beta, s)
# Out:
# 0.8 1.1498726106181565 0.6692432055703005 -0.2 0.5712204641532995 0.2695592224886201

# %% [markdown]
# ##### Loop:

# %%
# We plot s(m) and beta(m) for different e

s_tab = np.zeros((4,10))
beta_tab = np.zeros((4,10))
for i,e in tqdm(enumerate(np.linspace(-0.5,-0.2,4)),total=4):
    for j,m in enumerate(np.linspace(0.,0.6,10)):
        q0=0.5
        J0star = scipy.optimize.root(lambda J0: find_m(m,e,q0,J0)-m, 0.1).x[0]
        q = iterate_q(m,J0star,q0,e)
        beta = beta_q_e(q,e)
        s = compute_s(m,J0star,q,e)
        s_tab[i,j] = s
        beta_tab[i,j] = beta

fig,ax = plt.subplots(1,2,figsize=(10,5))
for i in range(4):
    ax[0].plot(np.linspace(0.,0.5,10),s_tab[i,:],label='e='+str(np.linspace(-0.5,-0.2,4)[i]))
    ax[0].set_xlabel('m')
    ax[0].set_ylabel('s')   
    ax[1].plot(np.linspace(0.,0.5,10),beta_tab[i,:],label='e='+str(np.linspace(-0.5,-0.2,4)[i]))
    ax[1].set_xlabel('m')
    ax[1].set_ylabel('beta')
plt.legend()
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
